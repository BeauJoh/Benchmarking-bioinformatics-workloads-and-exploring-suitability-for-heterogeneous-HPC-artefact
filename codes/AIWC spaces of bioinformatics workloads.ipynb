# %% [markdown]
# # Bioinformatics Applications From EOD
#
# * dynamic-programming/nw and
# * dynamic-programming/swat -- sequence analysis (why do we have both of these – does it improve coverage in any way?)
# * n-body-methods/gem (biophysics)
# * graphical-models/hmm (sequence analysis, gene expression)
# * mapreduce/kmeans (pattern identification, gene similarity)
# * finite-state-machine/tdm (sequence analysis)
# * graph-traversal/bfs (sequence analysis)
# * unstructured-grids/cfd (if it were used to model cardiovascular flow)
#
# Set up:

# %%
# %load_ext rpy2.ipython
# %env PROBLEM_SIZE=tiny
# Out:
# env: PROBLEM_SIZE=tiny

# %% [markdown]
# ## Dynamic Programming
#
# ### nw
#
# Generate nw results:

# %%
# %cd /OpenDwarfs/build
! $OCLGRIND_BIN --workload-characterisation ./needle -p 0 -d 0 -t 0 -- 2048 10
! rm -f lsb.*.r0* #we aren't interested in runtime data
# Out:
# /OpenDwarfs/build
# Opt.optimized = 0
# CPU was selected
# Platform Chosen : University of Bristol
# Number of available devices: 1
# Device Chosen : Oclgrind Simulator
# ***** LSB_Init >needle< writing to >lsb.needle.r0< *****
# Start Needleman-Wunsch
# Device type is Default
# Kernel file needle_kernel.cl: Defines =  -DOPENCL -I.
# Working kernel memory: 32800.007812KiB
# Processing top-left matrix
# Architecture-Independent Workload Characterization of kernel: needle_opencl_shared_1
# +----------------------------------------------------------------------------+
# |Compute Opcode Instruction Histogram                                        |
# +============================================================================+
# instruction: sext count: 1024
# instruction: call count: 784
# instruction: phi count: 528
# instruction: shl count: 16
# instruction: trunc count: 32
# instruction: add count: 1464
# instruction: br count: 1808
# instruction: select count: 512
# ...

# %% [markdown]
# Load the data:

# %%
# %cd /workspace/codes/

#TODO: Add number of kernel invocations to kiviat diagram -- as a compute metric?

# %% [markdown]
# Visualize the feature-space:

# %%
# %%R -i aiwc -w 800 -h 800 -u px

# %% [markdown]
# ### swat
